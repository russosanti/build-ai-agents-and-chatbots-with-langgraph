# %%
#Install all dependency packages for the course
#Remember to execute this before running any of the exercises
# !pip install tenacity==9.0.0
# !pip install langchain==0.3.12
# !pip install langchain-openai==0.2.12
# !pip install langchain_community==0.3.12
# !pip install langgraph==0.2.59
# !pip install pysqlite3-binary==0.5.4
# !pip install langchain_chroma==0.1.4
# !pip install pandas==2.2.3
# !pip install pypdf==5.1.0
# !pip install nbformat==5.10.4
# Out:
# Requirement already satisfied: tenacity==9.0.0 in ./venv/lib/python3.13/site-packages (9.0.0)
# Requirement already satisfied: langchain==0.3.12 in ./venv/lib/python3.13/site-packages (0.3.12)
# Requirement already satisfied: PyYAML>=5.3 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (3.13.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (0.3.63)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (0.3.8)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (2.13.3)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (2.33.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in ./venv/lib/python3.13/site-packages (from langchain==0.3.12) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (1.23.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.25->langchain==0.3.12) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.25->langchain==0.3.12) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.25->langchain==0.3.12) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain==0.3.12) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.12) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./venv/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.12) (3.11.8)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./venv/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.12) (1.0.0)
# Requirement already satisfied: anyio in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.12) (4.13.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.12) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.12) (1.0.9)
# Requirement already satisfied: idna in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.12) (3.13)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.12) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.12) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in ./venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.12) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.12) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.12) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.12) (2.6.3)
# Requirement already satisfied: langchain-openai==0.2.12 in ./venv/lib/python3.13/site-packages (0.2.12)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in ./venv/lib/python3.13/site-packages (from langchain-openai==0.2.12) (0.3.63)
# Requirement already satisfied: openai<2.0.0,>=1.55.3 in ./venv/lib/python3.13/site-packages (from langchain-openai==0.2.12) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./venv/lib/python3.13/site-packages (from langchain-openai==0.2.12) (0.12.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.2.11)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (6.0.3)
# Requirement already satisfied: packaging<25,>=23.2 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (4.15.0)
# Requirement already satisfied: pydantic>=2.7.4 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2.13.3)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (3.11.8)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2.33.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (1.0.0)
# Requirement already satisfied: anyio in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (4.13.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (1.0.9)
# Requirement already satisfied: idna in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (3.13)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (0.14.0)
# Requirement already satisfied: sniffio in ./venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in ./venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2.6.3)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.12) (2026.4.4)
# Requirement already satisfied: langchain_community==0.3.12 in ./venv/lib/python3.13/site-packages (0.3.12)
# Requirement already satisfied: PyYAML>=5.3 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (0.4.3)
# Requirement already satisfied: langchain<0.4.0,>=0.3.12 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (0.3.12)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (0.3.63)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (2.14.0)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (2.33.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in ./venv/lib/python3.13/site-packages (from langchain_community==0.3.12) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.12) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.12) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.12) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.12) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.12) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.12) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.12) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.3.12) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.3.12) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in ./venv/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.12->langchain_community==0.3.12) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./venv/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.12->langchain_community==0.3.12) (2.13.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.25->langchain_community==0.3.12) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.25->langchain_community==0.3.12) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.25->langchain_community==0.3.12) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain_community==0.3.12) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain_community==0.3.12) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./venv/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain_community==0.3.12) (3.11.8)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./venv/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain_community==0.3.12) (1.0.0)
# Requirement already satisfied: anyio in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community==0.3.12) (4.13.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community==0.3.12) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community==0.3.12) (1.0.9)
# Requirement already satisfied: idna in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community==0.3.12) (3.13)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community==0.3.12) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.12->langchain_community==0.3.12) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in ./venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.12->langchain_community==0.3.12) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.12->langchain_community==0.3.12) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./venv/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community==0.3.12) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langchain_community==0.3.12) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langchain_community==0.3.12) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community==0.3.12) (1.1.0)
# Requirement already satisfied: langgraph==0.2.59 in ./venv/lib/python3.13/site-packages (0.2.59)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in ./venv/lib/python3.13/site-packages (from langgraph==0.2.59) (0.3.63)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.4 in ./venv/lib/python3.13/site-packages (from langgraph==0.2.59) (2.1.2)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in ./venv/lib/python3.13/site-packages (from langgraph==0.2.59) (0.1.74)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in ./venv/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (0.2.11)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venv/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in ./venv/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (6.0.3)
# Requirement already satisfied: packaging<25,>=23.2 in ./venv/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in ./venv/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (4.15.0)
# Requirement already satisfied: pydantic>=2.7.4 in ./venv/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (2.13.3)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.10.0 in ./venv/lib/python3.13/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.4->langgraph==0.2.59) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in ./venv/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.59) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in ./venv/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.59) (3.11.8)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (2.33.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (1.0.0)
# Requirement already satisfied: anyio in ./venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.59) (4.13.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.59) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.59) (1.0.9)
# Requirement already satisfied: idna in ./venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.59) (3.13)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.59) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in ./venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.59) (2.6.3)
# ERROR: Could not find a version that satisfies the requirement pysqlite3-binary==0.5.4 (from versions: none)
# ERROR: No matching distribution found for pysqlite3-binary==0.5.4
# Requirement already satisfied: langchain_chroma==0.1.4 in ./venv/lib/python3.13/site-packages (0.1.4)
# Requirement already satisfied: chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 in ./venv/lib/python3.13/site-packages (from langchain_chroma==0.1.4) (0.5.23)
# Requirement already satisfied: fastapi<1,>=0.95.2 in ./venv/lib/python3.13/site-packages (from langchain_chroma==0.1.4) (0.136.0)
# Requirement already satisfied: langchain-core<0.4,>=0.1.40 in ./venv/lib/python3.13/site-packages (from langchain_chroma==0.1.4) (0.3.63)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in ./venv/lib/python3.13/site-packages (from langchain_chroma==0.1.4) (1.26.4)
# Requirement already satisfied: build>=1.0.3 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.4.4)
# Requirement already satisfied: pydantic>=1.9 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (2.13.3)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in ./venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.45.0)
# Requirement already satisfied: posthog>=2.4.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (7.13.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.25.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.41.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.41.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.62b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.41.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (7.7.0)
# Requirement already satisfied: importlib-resources in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.24.2)
# Requirement already satisfied: kubernetes>=28.1.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (3.11.8)
# Requirement already satisfied: httpx>=0.27.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in ./venv/lib/python3.13/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (15.0.0)
# Requirement already satisfied: starlette>=0.46.0 in ./venv/lib/python3.13/site-packages (from fastapi<1,>=0.95.2->langchain_chroma==0.1.4) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.13/site-packages (from fastapi<1,>=0.95.2->langchain_chroma==0.1.4) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./venv/lib/python3.13/site-packages (from fastapi<1,>=0.95.2->langchain_chroma==0.1.4) (0.0.4)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma==0.1.4) (0.2.11)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma==0.1.4) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./venv/lib/python3.13/site-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma==0.1.4) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1.40->langchain_chroma==0.1.4) (3.1.1)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.1.40->langchain_chroma==0.1.4) (2.33.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.1.40->langchain_chroma==0.1.4) (1.0.0)
# Requirement already satisfied: anyio in ./venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (4.13.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.0.9)
# Requirement already satisfied: idna in ./venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (3.13)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.13/site-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in ./venv/lib/python3.13/site-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (2.46.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.1.40->langchain_chroma==0.1.4) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.1.40->langchain_chroma==0.1.4) (2.6.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./venv/lib/python3.13/site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.36.2)
# Requirement already satisfied: filelock in ./venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.4.3)
# Requirement already satisfied: pyproject_hooks in ./venv/lib/python3.13/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.2.0)
# Requirement already satisfied: six>=1.9.0 in ./venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.9.0)
# Requirement already satisfied: requests-oauthlib in ./venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in ./venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.10)
# Requirement already satisfied: flatbuffers in ./venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (25.12.19)
# Requirement already satisfied: protobuf in ./venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (6.33.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in ./venv/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in ./venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.0 in ./venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.41.0)
# Requirement already satisfied: opentelemetry-proto==1.41.0 in ./venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.41.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in ./venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.62b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.62b0 in ./venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.62b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.62b0 in ./venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.62b0)
# Requirement already satisfied: opentelemetry-util-http==0.62b0 in ./venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.62b0)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in ./venv/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.62b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (2.1.2)
# Requirement already satisfied: asgiref~=3.0 in ./venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asgi==0.62b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (3.11.1)
# Requirement already satisfied: backoff>=1.10.0 in ./venv/lib/python3.13/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in ./venv/lib/python3.13/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.1.2)
# Requirement already satisfied: click>=8.2.1 in ./venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in ./venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in ./venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in ./venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.2.2)
# Requirement already satisfied: uvloop>=0.15.1 in ./venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in ./venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in ./venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./venv/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma==0.1.4) (3.3.1)
# Requirement already satisfied: pandas==2.2.3 in ./venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in ./venv/lib/python3.13/site-packages (from pandas==2.2.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.13/site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.13/site-packages (from pandas==2.2.3) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.13/site-packages (from pandas==2.2.3) (2026.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# Requirement already satisfied: pypdf==5.1.0 in ./venv/lib/python3.13/site-packages (5.1.0)
# Requirement already satisfied: nbformat==5.10.4 in ./venv/lib/python3.13/site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in ./venv/lib/python3.13/site-packages (from nbformat==5.10.4) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in ./venv/lib/python3.13/site-packages (from nbformat==5.10.4) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./venv/lib/python3.13/site-packages (from nbformat==5.10.4) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in ./venv/lib/python3.13/site-packages (from nbformat==5.10.4) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in ./venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat==5.10.4) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat==5.10.4) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat==5.10.4) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat==5.10.4) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat==5.10.4) (4.9.6)

# %% [markdown]
# ## 2.3. Setup Function Tools for ReAct Agent

# %%
from langchain_core.tools import tool

#Tool annotation identifies a function as a tool automatically
@tool
def find_sum(x:int, y:int) -> int :
    #The docstring comment describes the capabilities of the function
    #It is used by the agent to discover the function's inputs, outputs and capabilities
    """
    This function is used to add two numbers and return their sum.
    It takes two integers as inputs and returns an integer as output.
    """
    return x + y

@tool
def find_product(x:int, y:int) -> int :
    """
    This function is used to multiply two numbers and return their product.
    It takes two integers as inputs and returns an integer as ouput.
    """
    return x * y

# %% [markdown]
# ## 2.4. Create a basic ReAct Agent

# %%
from langchain_openai import AzureChatOpenAI
import os
#Setup the LLM for the agent

#API info. Replace with your own keys and end points
os.environ["AZURE_OPENAI_API_KEY"]="afsdasdfsadf"
os.environ["AZURE_OPENAI_ENDPOINT"]="https://santi-open-ai.openai.azure.com/"

#Setup the LLM
model = AzureChatOpenAI(
    azure_deployment="gpt-4o" ,
    api_version="2023-03-15-preview",
    model="gpt-4o"
)

#Test the model
#response = llm.invoke("Hello, how are you?")
#print(response.content)

# %%
from langgraph.prebuilt import create_react_agent
from langchain_core.messages import AIMessage,HumanMessage,SystemMessage

#Create list of tools available to the agent
agent_tools=[find_sum, find_product]

#System prompt
system_prompt = SystemMessage(
    """You are a Math genius who can solve math problems. Solve the
    problems provided by the user, by using only tools available. 
    Do not solve the problem yourself"""
)

agent_graph=create_react_agent(
    model=model, 
    state_modifier=system_prompt,
    tools=agent_tools)

# %% [markdown]
# ## 2.5. Execute the ReAct Agent

# %%
#Example 1
inputs = {"messages":[("user","what is the sum of 2 and 3 ?")]}

result = agent_graph.invoke(inputs)

#Get the final answer
print(f"Agent returned : {result['messages'][-1].content} \n")

print("Step by Step execution : ")
for message in result['messages']:
    print(message.pretty_repr())
# Out:
# Agent returned : The sum of 2 and 3 is 5.
#
# Step by Step execution :
# ================================ Human Message =================================
#
# what is the sum of 2 and 3 ?
# ================================== Ai Message ==================================
# Tool Calls:
#   find_sum (call_G4DhTdCh4rKR4TAWkfVn7E0b)
#  Call ID: call_G4DhTdCh4rKR4TAWkfVn7E0b
#   Args:
#     x: 2
#     y: 3
# ================================= Tool Message =================================
# Name: find_sum
#
# 5
# ================================== Ai Message ==================================
#
# The sum of 2 and 3 is 5.

# %%
#Example 2
inputs = {"messages":[("user","What is 3 multipled by 2 and 5 + 1 ?")]}

result = agent_graph.invoke(inputs)

#Get the final answer
print(f"Agent returned : {result['messages'][-1].content} \n")

print("Step by Step execution : ")
for message in result['messages']:
    print(message.pretty_repr())
# Out:
# Agent returned : 3 multiplied by 2 is 6, and 5 + 1 is also 6.
#
# Step by Step execution :
# ================================ Human Message =================================
#
# What is 3 multipled by 2 and 5 + 1 ?
# ================================== Ai Message ==================================
# Tool Calls:
#   find_product (call_nlwakLV1BZaIgMUHBW7phBPj)
#  Call ID: call_nlwakLV1BZaIgMUHBW7phBPj
#   Args:
#     x: 3
#     y: 2
#   find_sum (call_Pz14Bpqzsv63UdQK7znMElqO)
#  Call ID: call_Pz14Bpqzsv63UdQK7znMElqO
#   Args:
#     x: 5
#     y: 1
# ================================= Tool Message =================================
# Name: find_product
#
# 6
# ================================= Tool Message =================================
# Name: find_sum
#
# 6
# ================================== Ai Message ==================================
#
# 3 multiplied by 2 is 6, and 5 + 1 is also 6.

# %% [markdown]
# ## 2.6. Debugging the Agent

# %%
agent_graph=create_react_agent(
    model=model, 
    state_modifier=system_prompt,
    tools=agent_tools,
    debug=True)

inputs = {"messages":[("user","what is the sum of 2 and 3 ?")]}

result = agent_graph.invoke(inputs)
# Out:
# [-1:checkpoint] State at the end of step -1:
# {'messages': []}
# [0:tasks] Starting 1 task for step 0:
# - __start__ -> {'messages': [('user', 'what is the sum of 2 and 3 ?')]}
# [0:writes] Finished step 0 with writes to 1 channel:
# - messages -> [('user', 'what is the sum of 2 and 3 ?')]
# [0:checkpoint] State at the end of step 0:
# {'messages': [HumanMessage(content='what is the sum of 2 and 3 ?', additional_kwargs={}, response_metadata={}, id='a4364fc8-0afc-4f46-971a-ea1acff7f3a1')]}
# [1:tasks] Starting 1 task for step 1:
# - agent -> {'is_last_step': False,
#  'messages': [HumanMessage(content='what is the sum of 2 and 3 ?', additional_kwargs={}, response_metadata={}, id='a4364fc8-0afc-4f46-971a-ea1acff7f3a1')],
#  'remaining_steps': 24}
# [1:writes] Finished step 1 with writes to 1 channel:
# - messages -> [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'function': {'arguments': '{"x":2,"y":3}', 'name': 'find_sum'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 159, 'total_tokens': 177, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_04751d0b65', 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='run-d90f1b42-6c38-4d8c-8e98-9e735d5ba144-0', tool_calls=[{'name': 'find_sum', 'args': {'x': 2, 'y': 3}, 'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 159, 'output_tokens': 18, 'total_tokens': 177, 'input_token_details': {}, 'output_token_details': {}})]
# [1:checkpoint] State at the end of step 1:
# {'messages': [HumanMessage(content='what is the sum of 2 and 3 ?', additional_kwargs={}, response_metadata={}, id='a4364fc8-0afc-4f46-971a-ea1acff7f3a1'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'function': {'arguments': '{"x":2,"y":3}', 'name': 'find_sum'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 159, 'total_tokens': 177, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_04751d0b65', 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='run-d90f1b42-6c38-4d8c-8e98-9e735d5ba144-0', tool_calls=[{'name': 'find_sum', 'args': {'x': 2, 'y': 3}, 'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 159, 'output_tokens': 18, 'total_tokens': 177, 'input_token_details': {}, 'output_token_details': {}})]}
# [2:tasks] Starting 1 task for step 2:
# - tools -> {'is_last_step': False,
#  'messages': [HumanMessage(content='what is the sum of 2 and 3 ?', additional_kwargs={}, response_metadata={}, id='a4364fc8-0afc-4f46-971a-ea1acff7f3a1'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'function': {'arguments': '{"x":2,"y":3}', 'name': 'find_sum'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 159, 'total_tokens': 177, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_04751d0b65', 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='run-d90f1b42-6c38-4d8c-8e98-9e735d5ba144-0', tool_calls=[{'name': 'find_sum', 'args': {'x': 2, 'y': 3}, 'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 159, 'output_tokens': 18, 'total_tokens': 177, 'input_token_details': {}, 'output_token_details': {}})],
#  'remaining_steps': 23}
# [2:writes] Finished step 2 with writes to 1 channel:
# - messages -> [ToolMessage(content='5', name='find_sum', tool_call_id='call_sLAPT3bdzKiVm0Qy6jiQ86z6')]
# [2:checkpoint] State at the end of step 2:
# {'messages': [HumanMessage(content='what is the sum of 2 and 3 ?', additional_kwargs={}, response_metadata={}, id='a4364fc8-0afc-4f46-971a-ea1acff7f3a1'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'function': {'arguments': '{"x":2,"y":3}', 'name': 'find_sum'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 159, 'total_tokens': 177, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_04751d0b65', 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='run-d90f1b42-6c38-4d8c-8e98-9e735d5ba144-0', tool_calls=[{'name': 'find_sum', 'args': {'x': 2, 'y': 3}, 'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 159, 'output_tokens': 18, 'total_tokens': 177, 'input_token_details': {}, 'output_token_details': {}}),
#               ToolMessage(content='5', name='find_sum', id='5c097231-1471-4a03-a864-54412526ce77', tool_call_id='call_sLAPT3bdzKiVm0Qy6jiQ86z6')]}
# [3:tasks] Starting 1 task for step 3:
# - agent -> {'is_last_step': False,
#  'messages': [HumanMessage(content='what is the sum of 2 and 3 ?', additional_kwargs={}, response_metadata={}, id='a4364fc8-0afc-4f46-971a-ea1acff7f3a1'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'function': {'arguments': '{"x":2,"y":3}', 'name': 'find_sum'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 159, 'total_tokens': 177, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_04751d0b65', 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='run-d90f1b42-6c38-4d8c-8e98-9e735d5ba144-0', tool_calls=[{'name': 'find_sum', 'args': {'x': 2, 'y': 3}, 'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 159, 'output_tokens': 18, 'total_tokens': 177, 'input_token_details': {}, 'output_token_details': {}}),
#               ToolMessage(content='5', name='find_sum', id='5c097231-1471-4a03-a864-54412526ce77', tool_call_id='call_sLAPT3bdzKiVm0Qy6jiQ86z6')],
#  'remaining_steps': 22}
# [3:writes] Finished step 3 with writes to 1 channel:
# - messages -> [AIMessage(content='The sum of 2 and 3 is 5.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 186, 'total_tokens': 199, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_04751d0b65', 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {}}, id='run-1331ed90-821c-4a2e-ac1e-8f76f5999208-0', usage_metadata={'input_tokens': 186, 'output_tokens': 13, 'total_tokens': 199, 'input_token_details': {}, 'output_token_details': {}})]
# [3:checkpoint] State at the end of step 3:
# {'messages': [HumanMessage(content='what is the sum of 2 and 3 ?', additional_kwargs={}, response_metadata={}, id='a4364fc8-0afc-4f46-971a-ea1acff7f3a1'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'function': {'arguments': '{"x":2,"y":3}', 'name': 'find_sum'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 159, 'total_tokens': 177, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_04751d0b65', 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='run-d90f1b42-6c38-4d8c-8e98-9e735d5ba144-0', tool_calls=[{'name': 'find_sum', 'args': {'x': 2, 'y': 3}, 'id': 'call_sLAPT3bdzKiVm0Qy6jiQ86z6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 159, 'output_tokens': 18, 'total_tokens': 177, 'input_token_details': {}, 'output_token_details': {}}),
#               ToolMessage(content='5', name='find_sum', id='5c097231-1471-4a03-a864-54412526ce77', tool_call_id='call_sLAPT3bdzKiVm0Qy6jiQ86z6'),
#               AIMessage(content='The sum of 2 and 3 is 5.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 186, 'total_tokens': 199, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_04751d0b65', 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {}}, id='run-1331ed90-821c-4a2e-ac1e-8f76f5999208-0', usage_metadata={'input_tokens': 186, 'output_tokens': 13, 'total_tokens': 199, 'input_token_details': {}, 'output_token_details': {}})]}
